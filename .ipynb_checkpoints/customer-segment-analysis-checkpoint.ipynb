# %%
import pandas as pd # for data manupulation
import matplotlib.pyplot as plt # for plotting

# %%
df = pd.read_csv('travel_tide.csv') # load dataset

# %%
df
# Out:
#        user_id                               session_id  \
# 0       447951  447951-dc80e75ea3234c0398a9911953386d90
# 1       449980  449980-e740c9ba5e3945db803565a5239b6d2e
# 2       485785  485785-b77e273846f34973993dae383568a47c
# 3       487352  487352-58491d5ab9d84a34ae58e6ccb3ade0c3
# 4       489949  489949-a3eec794414a4e13a5929e73c7157f1b
# ...        ...                                      ...
# 49206   622343  622343-8de1e79234d94afca297fa7dee9af5ce
# 49207   480313  480313-f46ac4d965a2410e84ddf400ede116ad
# 49208   534295  534295-0a137c45cac34b1e834f23ecab4233fb
# 49209   518416  518416-fd45c188d94a4d30a7e4468056701f1e
# 49210   510093  510093-2d3e14a9e10b4a0a942a4312b914e557
#
#                                        trip_id        session_start  \
# 0                                          NaN  2023-01-04 20:35:00
# 1                                          NaN  2023-01-04 22:48:00
# 2                                          NaN  2023-01-05 18:24:00
# 3                                          NaN  2023-01-05 09:01:00
# 4                                          NaN  2023-01-05 20:58:00
# ...                                        ...                  ...
# 49206  622343-2061dc37f60d410f9af97a51a7c8b676  2023-07-20 18:42:37
# 49207  480313-129a85cc3c5244b5962afe10c7932cda  2023-02-09 22:01:16
# 49208  534295-3e20b84b40c946b1a8124395231d4412  2023-07-10 18:55:00
# 49209  518416-cca5cea3fac04cdf8d069e13891f016a  2023-07-15 07:38:00
# 49210  510093-e71475580a7c4948ba8f13114a60fa30  2023-07-18 17:06:00
#
#                       session_end  flight_discount  hotel_discount  \
# 0             2023-01-04 20:35:52            False           False
# 1             2023-01-04 22:50:10            False           False
# 2             2023-01-05 18:24:47             True           False
# 3             2023-01-05 09:03:29            False           False
# 4             2023-01-05 20:59:23            False           False
# ...                           ...              ...             ...
# 49206  2023-07-20 19:51:01.770539             True            True
# 49207         2023-02-10 00:01:16             True            True
# 49208         2023-07-10 18:57:18            False           False
# 49209         2023-07-15 07:42:04            False           False
# 49210         2023-07-18 17:08:42             True           False
#
#        flight_discount_amount  hotel_discount_amount  flight_booked  ...  \
# 0                         NaN                    NaN          False  ...
# 1                         NaN                    NaN          False  ...
# 2                        0.15                    NaN          False  ...
# 3                         NaN                    NaN          False  ...
# 4                         NaN                    NaN          False  ...
# ...                       ...                    ...            ...  ...
# 49206                     NaN                    NaN           True  ...
# 49207                     NaN                    NaN           True  ...
# 49208                     NaN                    NaN           True  ...
# 49209                     NaN                    NaN           True  ...
# 49210                    0.20                    NaN           True  ...
#
#        destination_airport_lat  destination_airport_lon  base_fare_usd  \
# 0                          NaN                      NaN            NaN
# 1                          NaN                      NaN            NaN
# 2                          NaN                      NaN            NaN
# 3                          NaN                      NaN            NaN
# 4                          NaN                      NaN            NaN
# ...                        ...                      ...            ...
# 49206                   40.640                  -73.779         214.03
# 49207                   37.362                 -121.929          83.44
# 49208                   32.699                 -117.215        3205.63
# 49209                   29.529                  -98.279         103.01
# 49210                   50.056                  -97.032         381.22
#
#                                      trip_id.2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 49206                                      NaN
# 49207  480313-129a85cc3c5244b5962afe10c7932cda
# 49208  534295-3e20b84b40c946b1a8124395231d4412
# 49209  518416-cca5cea3fac04cdf8d069e13891f016a
# 49210  510093-e71475580a7c4948ba8f13114a60fa30
#
#                             hotel_name  nights  rooms           check_in_time  \
# 0                                  NaN     NaN    NaN                     NaN
# 1                                  NaN     NaN    NaN                     NaN
# 2                                  NaN     NaN    NaN                     NaN
# 3                                  NaN     NaN    NaN                     NaN
# 4                                  NaN     NaN    NaN                     NaN
# ...                                ...     ...    ...                     ...
# 49206                              NaN     NaN    NaN                     NaN
# 49207            Shangri-La - san jose     2.0    1.0  2023-02-13 09:37:10.74
# 49208         Aman Resorts - san diego     8.0    4.0   2023-07-20 20:54:53.1
# 49209  InterContinental  - san antonio     1.0    2.0  2023-07-22 15:22:38.37
# 49210             Marriott  - winnipeg     0.0    1.0  2023-07-30 11:45:27.81
#
#             check_out_time hotel_per_room_usd
# 0                      NaN                NaN
# 1                      NaN                NaN
# 2                      NaN                NaN
# 3                      NaN                NaN
# 4                      NaN                NaN
# ...                    ...                ...
# 49206                  NaN                NaN
# 49207  2023-02-15 11:00:00              174.0
# 49208  2023-07-29 11:00:00               85.0
# 49209  2023-07-24 11:00:00               80.0
# 49210  2023-07-30 11:00:00              109.0
#
# [49211 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['user_id', 'session_id', 'trip_id', 'session_start', 'session_end',
#        'flight_discount', 'hotel_discount', 'flight_discount_amount',
#        'hotel_discount_amount', 'flight_booked', 'hotel_booked', 'page_clicks',
#        'cancellation', 'birthdate', 'gender', 'married', 'has_children',
#        'home_country', 'home_city', 'home_airport', 'home_airport_lat',
#        'home_airport_lon', 'sign_up_date', 'trip_id.1', 'origin_airport',
#        'destination', 'destination_airport', 'seats', 'return_flight_booked',
#        'departure_time', 'return_time', 'checked_bags', 'trip_airline',
#        'destination_airport_lat', 'destination_airport_lon', 'base_fare_usd',
#        'trip_id.2', 'hotel_name', 'nights', 'rooms', 'check_in_time',
#        'check_out_time', 'hotel_per_room_usd'],
#       dtype='object')

# %%
# df["nights"].fillna(0.0, inplace=True)

# %% [markdown]
# # Free Hotel Meal Perk

# %%
df['total_hotel_spent'] = df['rooms'] * df['hotel_per_room_usd'] * df['nights'] # total spend on hotel

# %%
df
# Out:
#        user_id                               session_id  \
# 0       447951  447951-dc80e75ea3234c0398a9911953386d90
# 1       449980  449980-e740c9ba5e3945db803565a5239b6d2e
# 2       485785  485785-b77e273846f34973993dae383568a47c
# 3       487352  487352-58491d5ab9d84a34ae58e6ccb3ade0c3
# 4       489949  489949-a3eec794414a4e13a5929e73c7157f1b
# ...        ...                                      ...
# 49206   622343  622343-8de1e79234d94afca297fa7dee9af5ce
# 49207   480313  480313-f46ac4d965a2410e84ddf400ede116ad
# 49208   534295  534295-0a137c45cac34b1e834f23ecab4233fb
# 49209   518416  518416-fd45c188d94a4d30a7e4468056701f1e
# 49210   510093  510093-2d3e14a9e10b4a0a942a4312b914e557
#
#                                        trip_id        session_start  \
# 0                                          NaN  2023-01-04 20:35:00
# 1                                          NaN  2023-01-04 22:48:00
# 2                                          NaN  2023-01-05 18:24:00
# 3                                          NaN  2023-01-05 09:01:00
# 4                                          NaN  2023-01-05 20:58:00
# ...                                        ...                  ...
# 49206  622343-2061dc37f60d410f9af97a51a7c8b676  2023-07-20 18:42:37
# 49207  480313-129a85cc3c5244b5962afe10c7932cda  2023-02-09 22:01:16
# 49208  534295-3e20b84b40c946b1a8124395231d4412  2023-07-10 18:55:00
# 49209  518416-cca5cea3fac04cdf8d069e13891f016a  2023-07-15 07:38:00
# 49210  510093-e71475580a7c4948ba8f13114a60fa30  2023-07-18 17:06:00
#
#                       session_end  flight_discount  hotel_discount  \
# 0             2023-01-04 20:35:52            False           False
# 1             2023-01-04 22:50:10            False           False
# 2             2023-01-05 18:24:47             True           False
# 3             2023-01-05 09:03:29            False           False
# 4             2023-01-05 20:59:23            False           False
# ...                           ...              ...             ...
# 49206  2023-07-20 19:51:01.770539             True            True
# 49207         2023-02-10 00:01:16             True            True
# 49208         2023-07-10 18:57:18            False           False
# 49209         2023-07-15 07:42:04            False           False
# 49210         2023-07-18 17:08:42             True           False
#
#        flight_discount_amount  hotel_discount_amount  flight_booked  ...  \
# 0                         NaN                    NaN          False  ...
# 1                         NaN                    NaN          False  ...
# 2                        0.15                    NaN          False  ...
# 3                         NaN                    NaN          False  ...
# 4                         NaN                    NaN          False  ...
# ...                       ...                    ...            ...  ...
# 49206                     NaN                    NaN           True  ...
# 49207                     NaN                    NaN           True  ...
# 49208                     NaN                    NaN           True  ...
# 49209                     NaN                    NaN           True  ...
# 49210                    0.20                    NaN           True  ...
#
#        destination_airport_lon  base_fare_usd  \
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2                          NaN            NaN
# 3                          NaN            NaN
# 4                          NaN            NaN
# ...                        ...            ...
# 49206                  -73.779         214.03
# 49207                 -121.929          83.44
# 49208                 -117.215        3205.63
# 49209                  -98.279         103.01
# 49210                  -97.032         381.22
#
#                                      trip_id.2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 49206                                      NaN
# 49207  480313-129a85cc3c5244b5962afe10c7932cda
# 49208  534295-3e20b84b40c946b1a8124395231d4412
# 49209  518416-cca5cea3fac04cdf8d069e13891f016a
# 49210  510093-e71475580a7c4948ba8f13114a60fa30
#
#                             hotel_name nights  rooms           check_in_time  \
# 0                                  NaN    NaN    NaN                     NaN
# 1                                  NaN    NaN    NaN                     NaN
# 2                                  NaN    NaN    NaN                     NaN
# 3                                  NaN    NaN    NaN                     NaN
# 4                                  NaN    NaN    NaN                     NaN
# ...                                ...    ...    ...                     ...
# 49206                              NaN    NaN    NaN                     NaN
# 49207            Shangri-La - san jose    2.0    1.0  2023-02-13 09:37:10.74
# 49208         Aman Resorts - san diego    8.0    4.0   2023-07-20 20:54:53.1
# 49209  InterContinental  - san antonio    1.0    2.0  2023-07-22 15:22:38.37
# 49210             Marriott  - winnipeg    0.0    1.0  2023-07-30 11:45:27.81
#
#             check_out_time hotel_per_room_usd total_hotel_spent
# 0                      NaN                NaN               NaN
# 1                      NaN                NaN               NaN
# 2                      NaN                NaN               NaN
# 3                      NaN                NaN               NaN
# 4                      NaN                NaN               NaN
# ...                    ...                ...               ...
# 49206                  NaN                NaN               NaN
# 49207  2023-02-15 11:00:00              174.0             348.0
# 49208  2023-07-29 11:00:00               85.0            2720.0
# 49209  2023-07-24 11:00:00               80.0             160.0
# 49210  2023-07-30 11:00:00              109.0               0.0
#
# [49211 rows x 44 columns]

# %%
new_df = df[['user_id', 'total_hotel_spent']] # get the related column
new_df
# Out:
#        user_id  total_hotel_spent
# 0       447951                NaN
# 1       449980                NaN
# 2       485785                NaN
# 3       487352                NaN
# 4       489949                NaN
# ...        ...                ...
# 49206   622343                NaN
# 49207   480313              348.0
# 49208   534295             2720.0
# 49209   518416              160.0
# 49210   510093                0.0
#
# [49211 rows x 2 columns]

# %%
# get total spending on hotel by each user, sort it descending order on total spent
new_df = new_df.groupby('user_id', as_index=False).sum('total_hotel_spent').sort_values('total_hotel_spent', ascending=False)

# %%
new_df
# Out:
#       user_id  total_hotel_spent
# 2675   534594            28114.0
# 5077   596863            27489.0
# 780    507805            27241.0
# 2954   539710            22619.0
# 5818   669329            22356.0
# ...       ...                ...
# 3244   544926             -349.0
# 4595   577534             -398.0
# 5064   596320             -477.0
# 2961   539868             -562.0
# 1393   515835             -575.0
#
# [5998 rows x 2 columns]

# %%
new_df['total_hotel_spent'].describe() # summery
# Out:
# count     5998.000000
# mean      1949.746582
# std       2335.797809
# min       -575.000000
# 25%        464.000000
# 50%       1256.000000
# 75%       2588.750000
# max      28114.000000
# Name: total_hotel_spent, dtype: float64

# %%
# df.loc[df['nights'] > 0].sort_values('total_stay', ascending=False)

# %%
new_df['total_hotel_spent'].hist() # plot histogram
# Out:
# <Axes: >

# %%
plt.boxplot(new_df['total_hotel_spent']) # plot boxplot
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1afc1171f50>,
#   <matplotlib.lines.Line2D at 0x1afbdfdd110>],
#  'caps': [<matplotlib.lines.Line2D at 0x1afc1651210>,
#   <matplotlib.lines.Line2D at 0x1afc152e5d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1afc1656390>],
#  'medians': [<matplotlib.lines.Line2D at 0x1afc1e8c210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1afbe1e51d0>],
#  'means': []}

# %%
# Calculate Q1, Q3, and IQR
Q1 = new_df['total_hotel_spent'].quantile(0.25)
Q3 = new_df['total_hotel_spent'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df_filtered = new_df[(new_df['total_hotel_spent'] >= lower_bound) & (new_df['total_hotel_spent'] <= upper_bound)]

print("Original DataFrame:")
print(new_df)
print("\nDataFrame after removing outliers:")
print(df_filtered)
# Out:
# Original DataFrame:
#       user_id  total_hotel_spent
# 2675   534594            28114.0
# 5077   596863            27489.0
# 780    507805            27241.0
# 2954   539710            22619.0
# 5818   669329            22356.0
# ...       ...                ...
# 3244   544926             -349.0
# 4595   577534             -398.0
# 5064   596320             -477.0
# 2961   539868             -562.0
# 1393   515835             -575.0
#
# [5998 rows x 2 columns]
#
# DataFrame after removing outliers:
#       user_id  total_hotel_spent
# 3576   551359             5770.0
# 5779   662596             5760.0
# 1778   520898             5760.0
# 5319   611839             5758.0
# 2750   535905             5755.0
# ...       ...                ...
# 3244   544926             -349.0
# 4595   577534             -398.0
# 5064   596320             -477.0
# 2961   539868             -562.0
# 1393   515835             -575.0
#
# [5644 rows x 2 columns]

# %%
df_filtered['total_hotel_spent'].hist()
# Out:
# <Axes: >

# %%
plt.boxplot(df_filtered['total_hotel_spent'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1afc1796010>,
#   <matplotlib.lines.Line2D at 0x1afc17973d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1afc167a550>,
#   <matplotlib.lines.Line2D at 0x1afc179c550>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1afc1794910>],
#  'medians': [<matplotlib.lines.Line2D at 0x1afc179d950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1afc179e990>],
#  'means': []}

# %%
df_filtered['total_hotel_spent'].describe()
# Out:
# count    5644.000000
# mean     1526.987420
# std      1389.714068
# min      -575.000000
# 25%       421.500000
# 50%      1157.000000
# 75%      2293.000000
# max      5770.000000
# Name: total_hotel_spent, dtype: float64

# %%
# Create conditional DataFrame column by np.select function.
# giving free meal perks
conditions = [new_df['total_hotel_spent'] > 2293]

choices = ['yes']
new_df['free_meal'] = np.select(conditions, choices, default='no')
print(new_df)
# Out:
#       user_id  total_hotel_spent free_meal
# 2675   534594            28114.0       yes
# 5077   596863            27489.0       yes
# 780    507805            27241.0       yes
# 2954   539710            22619.0       yes
# 5818   669329            22356.0       yes
# ...       ...                ...       ...
# 3244   544926             -349.0        no
# 4595   577534             -398.0        no
# 5064   596320             -477.0        no
# 2961   539868             -562.0        no
# 1393   515835             -575.0        no
#
# [5998 rows x 3 columns]

# %%
new_df[new_df['free_meal'] == 'yes'].count() # total users that got the perk
# Out:
# user_id              1764
# total_hotel_spent    1764
# free_meal            1764
# dtype: int64

# %%
segmented_df = new_df[['user_id', 'free_meal']]
segmented_df
# Out:
#       user_id free_meal
# 2675   534594       yes
# 5077   596863       yes
# 780    507805       yes
# 2954   539710       yes
# 5818   669329       yes
# ...       ...       ...
# 3244   544926        no
# 4595   577534        no
# 5064   596320        no
# 2961   539868        no
# 1393   515835        no
#
# [5998 rows x 2 columns]

# %% [markdown]
# # Free Checked Bag

# %%
df.columns
# Out:
# Index(['user_id', 'session_id', 'trip_id', 'session_start', 'session_end',
#        'flight_discount', 'hotel_discount', 'flight_discount_amount',
#        'hotel_discount_amount', 'flight_booked', 'hotel_booked', 'page_clicks',
#        'cancellation', 'birthdate', 'gender', 'married', 'has_children',
#        'home_country', 'home_city', 'home_airport', 'home_airport_lat',
#        'home_airport_lon', 'sign_up_date', 'trip_id.1', 'origin_airport',
#        'destination', 'destination_airport', 'seats', 'return_flight_booked',
#        'departure_time', 'return_time', 'checked_bags', 'trip_airline',
#        'destination_airport_lat', 'destination_airport_lon', 'base_fare_usd',
#        'trip_id.2', 'hotel_name', 'nights', 'rooms', 'check_in_time',
#        'check_out_time', 'hotel_per_room_usd', 'total_hotel_spent'],
#       dtype='object')

# %%
df
# Out:
#        user_id                               session_id  \
# 0       447951  447951-dc80e75ea3234c0398a9911953386d90
# 1       449980  449980-e740c9ba5e3945db803565a5239b6d2e
# 2       485785  485785-b77e273846f34973993dae383568a47c
# 3       487352  487352-58491d5ab9d84a34ae58e6ccb3ade0c3
# 4       489949  489949-a3eec794414a4e13a5929e73c7157f1b
# ...        ...                                      ...
# 49206   622343  622343-8de1e79234d94afca297fa7dee9af5ce
# 49207   480313  480313-f46ac4d965a2410e84ddf400ede116ad
# 49208   534295  534295-0a137c45cac34b1e834f23ecab4233fb
# 49209   518416  518416-fd45c188d94a4d30a7e4468056701f1e
# 49210   510093  510093-2d3e14a9e10b4a0a942a4312b914e557
#
#                                        trip_id        session_start  \
# 0                                          NaN  2023-01-04 20:35:00
# 1                                          NaN  2023-01-04 22:48:00
# 2                                          NaN  2023-01-05 18:24:00
# 3                                          NaN  2023-01-05 09:01:00
# 4                                          NaN  2023-01-05 20:58:00
# ...                                        ...                  ...
# 49206  622343-2061dc37f60d410f9af97a51a7c8b676  2023-07-20 18:42:37
# 49207  480313-129a85cc3c5244b5962afe10c7932cda  2023-02-09 22:01:16
# 49208  534295-3e20b84b40c946b1a8124395231d4412  2023-07-10 18:55:00
# 49209  518416-cca5cea3fac04cdf8d069e13891f016a  2023-07-15 07:38:00
# 49210  510093-e71475580a7c4948ba8f13114a60fa30  2023-07-18 17:06:00
#
#                       session_end  flight_discount  hotel_discount  \
# 0             2023-01-04 20:35:52            False           False
# 1             2023-01-04 22:50:10            False           False
# 2             2023-01-05 18:24:47             True           False
# 3             2023-01-05 09:03:29            False           False
# 4             2023-01-05 20:59:23            False           False
# ...                           ...              ...             ...
# 49206  2023-07-20 19:51:01.770539             True            True
# 49207         2023-02-10 00:01:16             True            True
# 49208         2023-07-10 18:57:18            False           False
# 49209         2023-07-15 07:42:04            False           False
# 49210         2023-07-18 17:08:42             True           False
#
#        flight_discount_amount  hotel_discount_amount  flight_booked  ...  \
# 0                         NaN                    NaN          False  ...
# 1                         NaN                    NaN          False  ...
# 2                        0.15                    NaN          False  ...
# 3                         NaN                    NaN          False  ...
# 4                         NaN                    NaN          False  ...
# ...                       ...                    ...            ...  ...
# 49206                     NaN                    NaN           True  ...
# 49207                     NaN                    NaN           True  ...
# 49208                     NaN                    NaN           True  ...
# 49209                     NaN                    NaN           True  ...
# 49210                    0.20                    NaN           True  ...
#
#        destination_airport_lon  base_fare_usd  \
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2                          NaN            NaN
# 3                          NaN            NaN
# 4                          NaN            NaN
# ...                        ...            ...
# 49206                  -73.779         214.03
# 49207                 -121.929          83.44
# 49208                 -117.215        3205.63
# 49209                  -98.279         103.01
# 49210                  -97.032         381.22
#
#                                      trip_id.2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 49206                                      NaN
# 49207  480313-129a85cc3c5244b5962afe10c7932cda
# 49208  534295-3e20b84b40c946b1a8124395231d4412
# 49209  518416-cca5cea3fac04cdf8d069e13891f016a
# 49210  510093-e71475580a7c4948ba8f13114a60fa30
#
#                             hotel_name nights  rooms           check_in_time  \
# 0                                  NaN    NaN    NaN                     NaN
# 1                                  NaN    NaN    NaN                     NaN
# 2                                  NaN    NaN    NaN                     NaN
# 3                                  NaN    NaN    NaN                     NaN
# 4                                  NaN    NaN    NaN                     NaN
# ...                                ...    ...    ...                     ...
# 49206                              NaN    NaN    NaN                     NaN
# 49207            Shangri-La - san jose    2.0    1.0  2023-02-13 09:37:10.74
# 49208         Aman Resorts - san diego    8.0    4.0   2023-07-20 20:54:53.1
# 49209  InterContinental  - san antonio    1.0    2.0  2023-07-22 15:22:38.37
# 49210             Marriott  - winnipeg    0.0    1.0  2023-07-30 11:45:27.81
#
#             check_out_time hotel_per_room_usd total_hotel_spent
# 0                      NaN                NaN               NaN
# 1                      NaN                NaN               NaN
# 2                      NaN                NaN               NaN
# 3                      NaN                NaN               NaN
# 4                      NaN                NaN               NaN
# ...                    ...                ...               ...
# 49206                  NaN                NaN               NaN
# 49207  2023-02-15 11:00:00              174.0             348.0
# 49208  2023-07-29 11:00:00               85.0            2720.0
# 49209  2023-07-24 11:00:00               80.0             160.0
# 49210  2023-07-30 11:00:00              109.0               0.0
#
# [49211 rows x 44 columns]

# %%
new_df = df[['user_id', 'checked_bags']] # getting the related column

# %%
# Calculate total checked bags for each user
# bag_counts = df.groupby('user_id')['checked_bags'].sum()

new_df = new_df.groupby('user_id', as_index=False).sum('checked_bags').sort_values('checked_bags', ascending=False)

# %%
new_df.head()
# Out:
#       user_id  checked_bags
# 1435   516283          17.0
# 2372   529602          12.0
# 1244   513807          11.0
# 5403   618157          11.0
# 3483   549450          10.0

# %%
new_df.checked_bags.describe()
# Out:
# count    5998.000000
# mean        1.410637
# std         1.447175
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max        17.000000
# Name: checked_bags, dtype: float64

# %%
plt.boxplot(new_df.checked_bags)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1afc1a9f6d0>,
#   <matplotlib.lines.Line2D at 0x1afc1aa4ad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1afc1aa5950>,
#   <matplotlib.lines.Line2D at 0x1afc1aa6710>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1afc1a9e710>],
#  'medians': [<matplotlib.lines.Line2D at 0x1afc1aa7490>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1afc1a70210>],
#  'means': []}

# %%
# Calculate Q1, Q3, and IQR
Q1 = new_df['checked_bags'].quantile(0.25)
Q3 = new_df['checked_bags'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df_filtered = new_df[(new_df['checked_bags'] >= lower_bound) & (new_df['checked_bags'] <= upper_bound)]

print("Original DataFrame:")
print(new_df)
print("\nDataFrame after removing outliers:")
print(df_filtered)
# Out:
# Original DataFrame:
#       user_id  checked_bags
# 1435   516283          17.0
# 2372   529602          12.0
# 1244   513807          11.0
# 5403   618157          11.0
# 3483   549450          10.0
# ...       ...           ...
# 3227   544536           0.0
# 3233   544647           0.0
# 3238   544698           0.0
# 3240   544749           0.0
# 5997   844489           0.0
#
# [5998 rows x 2 columns]
#
# DataFrame after removing outliers:
#       user_id  checked_bags
# 2962   539883           5.0
# 5110   598911           5.0
# 154    413658           5.0
# 4114   563896           5.0
# 1439   516301           5.0
# ...       ...           ...
# 3227   544536           0.0
# 3233   544647           0.0
# 3238   544698           0.0
# 3240   544749           0.0
# 5997   844489           0.0
#
# [5913 rows x 2 columns]

# %%
plt.boxplot(df_filtered.checked_bags)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1afc1ba5010>,
#   <matplotlib.lines.Line2D at 0x1afc1ba7a90>],
#  'caps': [<matplotlib.lines.Line2D at 0x1afc1baa550>,
#   <matplotlib.lines.Line2D at 0x1afc1ba8290>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1afbde3cf50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1afc1baa3d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1afc1bb77d0>],
#  'means': []}

# %%
df_filtered.checked_bags.describe()
# Out:
# count    5913.000000
# mean        1.325385
# std         1.249760
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: checked_bags, dtype: float64

# %%
new_df[new_df['checked_bags'] > 2].count()
# Out:
# user_id         1101
# checked_bags    1101
# dtype: int64

# %%
# Create conditional DataFrame column by np.select function.
# giving the perk who has more than 2 checked bags
conditions = [new_df['checked_bags'] > 2]

choices = ['yes']
new_df['free_checked_bags'] = np.select(conditions, choices, default='no')
print(new_df)
# Out:
#       user_id  checked_bags free_checked_bags
# 1435   516283          17.0               yes
# 2372   529602          12.0               yes
# 1244   513807          11.0               yes
# 5403   618157          11.0               yes
# 3483   549450          10.0               yes
# ...       ...           ...               ...
# 3227   544536           0.0                no
# 3233   544647           0.0                no
# 3238   544698           0.0                no
# 3240   544749           0.0                no
# 5997   844489           0.0                no
#
# [5998 rows x 3 columns]

# %%
# merging to main segmented dataset
segmented_df = pd.merge(segmented_df, new_df[['user_id', 'free_checked_bags']], on='user_id', how='inner')
segmented_df
# Out:
#       user_id free_meal free_checked_bags
# 0      534594       yes                no
# 1      596863       yes               yes
# 2      507805       yes               yes
# 3      539710       yes                no
# 4      669329       yes                no
# ...       ...       ...               ...
# 5993   544926        no                no
# 5994   577534        no                no
# 5995   596320        no                no
# 5996   539868        no                no
# 5997   515835        no                no
#
# [5998 rows x 3 columns]

# %% [markdown]
# # No Cancellation Fees

# %%
df.columns
# Out:
# Index(['user_id', 'session_id', 'trip_id', 'session_start', 'session_end',
#        'flight_discount', 'hotel_discount', 'flight_discount_amount',
#        'hotel_discount_amount', 'flight_booked', 'hotel_booked', 'page_clicks',
#        'cancellation', 'birthdate', 'gender', 'married', 'has_children',
#        'home_country', 'home_city', 'home_airport', 'home_airport_lat',
#        'home_airport_lon', 'sign_up_date', 'trip_id.1', 'origin_airport',
#        'destination', 'destination_airport', 'seats', 'return_flight_booked',
#        'departure_time', 'return_time', 'checked_bags', 'trip_airline',
#        'destination_airport_lat', 'destination_airport_lon', 'base_fare_usd',
#        'trip_id.2', 'hotel_name', 'nights', 'rooms', 'check_in_time',
#        'check_out_time', 'hotel_per_room_usd'],
#       dtype='object')

# %%
df[df['cancellation'] == True]
# Out:
#        user_id                               session_id  \
# 2518    416580  416580-8058a404b4a0469badcd72ab3ea54e74
# 2534    539528  539528-c40b231e778a4b3d979900337298eec4
# 2535    624497  624497-3ef1f4bb9e5549669b28692895125374
# 2536    572489  572489-d55e3ccd0fa140409e240357fa0d1fbd
# 2552    511223  511223-4c94023f91d8407c9dd0945bc1911ee7
# ...        ...                                      ...
# 49155   486751  486751-8cd2671966064db4b5b3681ebb6530dd
# 49183   520539  520539-299ab3d56f534330abb1e021218b79ad
# 49205   438551  438551-f1073b8a5a844032a33256666ee6c47f
# 49206   622343  622343-8de1e79234d94afca297fa7dee9af5ce
# 49207   480313  480313-f46ac4d965a2410e84ddf400ede116ad
#
#                                        trip_id        session_start  \
# 2518   416580-2dc5394db1d54702b5ac5985b389dbd3  2023-01-24 23:01:48
# 2534   539528-700e1341a67648ae87bbf3f9cea98f05  2023-01-20 13:05:50
# 2535   624497-5d2f0fa3d91d413484a8455645282b38  2023-04-06 04:55:12
# 2536   572489-f754bd0bdb1b4068973d19dfa8e4ed33  2023-07-22 11:54:04
# 2552   511223-c139e9cd2553431ca9c1008bc49aefc3  2023-02-10 21:30:33
# ...                                        ...                  ...
# 49155  486751-ac8269b44cf44e37a344c955f34f6146  2023-02-24 16:40:25
# 49183  520539-ffb9736b5f6b44bd8628b3fbac49e7c7  2023-03-26 11:03:36
# 49205  438551-1a9fcfc16bd8487ea23e820957d23
# 49183    15.0    2.0  2023-10-29 22:35:42.315  2023-11-14 11:00:00
# 49205    13.0    3.0   2023-10-10 00:55:04.08  2023-10-23 11:00:00
# 49206     NaN    NaN                      NaN                  NaN
# 49207     2.0    1.0   2023-02-13 09:37:10.74  2023-02-15 11:00:00
#
#       hotel_per_room_usd
# 2518                80.0
# 2534               276.0
# 2535               116.0
# 2536                 NaN
# 2552               265.0
# ...                  ...
# 49155              177.0
# 49183              127.0
# 49205              143.0
# 49206                NaN
# 49207              174.0
#
# [610 rows x 43 columns]

# %%
# exclude cancel trip
no_cancel = df[df['cancellation'] != True]
no_cancel
# Out:
#        user_id                               session_id  \
# 0       447951  447951-dc80e75ea3234c0398a9911953386d90
# 1       449980  449980-e740c9ba5e3945db803565a5239b6d2e
# 2       485785  485785-b77e273846f34973993dae383568a47c
# 3       487352  487352-58491d5ab9d84a34ae58e6ccb3ade0c3
# 4       489949  489949-a3eec794414a4e13a5929e73c7157f1b
# ...        ...                                      ...
# 49203   551990  551990-572e2a6219bc40d8a6c1f583820533f0
# 49204   435231  435231-9f9d9e0971564942a7c8775c50812598
# 49208   534295  534295-0a137c45cac34b1e834f23ecab4233fb
# 49209   518416  518416-fd45c188d94a4d30a7e4468056701f1e
# 49210   510093  510093-2d3e14a9e10b4a0a942a4312b914e557
#
#                                        trip_id        session_start  \
# 0                                          NaN  2023-01-04 20:35:00
# 1                                          NaN  2023-01-04 22:48:00
# 2                                          NaN  2023-01-05 18:24:00
# 3                                          NaN  2023-01-05 09:01:00
# 4                                          NaN  2023-01-05 20:58:00
# ...                                        ...                  ...
# 49203  551990-fbb5ba1d6f1f43b58c6bc56e6b6dd288  2023-07-06 15:26:00
# 49204  435231-203cc75819b846d59b96b38788174dd5  2023-07-12 19:13:00
# 49208  534295-3e20b84b40c946b1a8124395231d4412  2023-07-10 18:55:00
# 49209  518416-cca5cea3fac04cdf8d069e13891f016a  2023-07-15 07:38:00
# 49210  510093-e71475580a7c4948ba8f13114a60fa30  2023-07-18 17:06:00
#
#                session_end  flight_discount  hotel_discount  \
# 0      2023-01-04 20:35:52            False           False
# 1      2023-01-04 22:50:10            False           False
# 2      2023-01-05 18:24:47             True           False
# 3      2023-01-05 09:03:29            False           False
# 4      2023-01-05 20:59:23            False           False
# ...                    ...              ...             ...
# 49203  2023-07-06 15:27:54            False           False
# 49204  2023-07-12 19:16:08            False           False
# 49208  2023-07-10 18:57:18            False           False
# 49209  2023-07-15 07:42:04            False           False
# 49210  2023-07-18 17:08:42             True           False
#
#        flight_discount_amount  hotel_discount_amount  flight_booked  ...  \
# 0                         NaN                    NaN          False  ...
# 1                         NaN                    NaN          False  ...
# 2                        0.15                    NaN          False  ...
# 3                         NaN                    NaN          False  ...
# 4                         NaN                    NaN          False  ...
# ...                       ...                    ...            ...  ...
# 49203                     NaN                    NaN          False  ...
# 49204                     NaN                    NaN           True  ...
# 49208                     NaN                    NaN           True  ...
# 49209                     NaN                    NaN           True  ...
# 49210                    0.20                    NaN           True  ...
#
#        destination_airport_lon  base_fare_usd  \
# 0                          NaN            NaN
# 1                          NaN            NaN
# 2                          NaN            NaN
# 3                          NaN            NaN
# 4                          NaN            NaN
# ...                        ...            ...
# 49203                      NaN            NaN
# 49204                  -83.010          52.88
# 49208                 -117.215        3205.63
# 49209                  -98.279         103.01
# 49210                  -97.032         381.22
#
#                                      trip_id.2  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 49203  551990-fbb5ba1d6f1f43b58c6bc56e6b6dd288
# 49204  435231-203cc75819b846d59b96b38788174dd5
# 49208  534295-3e20b84b40c946b1a8124395231d4412
# 49209  518416-cca5cea3fac04cdf8d069e13891f016a
# 49210  510093-e71475580a7c4948ba8f13114a60fa30
#
#                             hotel_name nights  rooms            check_in_time  \
# 0                                  NaN    NaN    NaN                      NaN
# 1                                  NaN    NaN    NaN                      NaN
# 2                                  NaN    NaN    NaN                      NaN
# 3                                  NaN    NaN    NaN                      NaN
# 4                                  NaN    NaN    NaN                      NaN
# ...                                ...    ...    ...                      ...
# 49203              Starwood  - chicago   17.0    1.0      2023-07-16 11:00:00
# 49204              Marriott  - detroit    2.0    1.0  2023-07-18 16:24:16.785
# 49208         Aman Resorts - san diego    8.0    4.0    2023-07-20 20:54:53.1
# 49209  InterContinental  - san antonio    1.0    2.0   2023-07-22 15:22:38.37
# 49210             Marriott  - winnipeg    0.0    1.0   2023-07-30 11:45:27.81
#
#             check_out_time hotel_per_room_usd total_hotel_spent
# 0                      NaN                NaN               NaN
# 1                      NaN                NaN               NaN
# 2                      NaN                NaN               NaN
# 3                      NaN                NaN               NaN
# 4                      NaN                NaN               NaN
# ...                    ...                ...               ...
# 49203  2023-08-02 11:00:00              175.0            2975.0
# 49204  2023-07-21 11:00:00               83.0             166.0
# 49208  2023-07-29 11:00:00               85.0            2720.0
# 49209  2023-07-24 11:00:00               80.0             160.0
# 49210  2023-07-30 11:00:00              109.0               0.0
#
# [48601 rows x 44 columns]

# %%
new_df = no_cancel[['user_id', 'trip_id']] # get the related column

# %%
# get the total trip by each user
new_df = new_df.groupby('user_id', as_index=False)['trip_id'].count().sort_values('trip_id', ascending=False)

# %%
new_df
# Out:
#       user_id  trip_id
# 469    485544        8
# 824    509115        8
# 1519   517491        8
# 4438   572554        8
# 1190   513236        8
# ...       ...      ...
# 2656   534082        0
# 2674   534586        0
# 817    509001        0
# 815    508964        0
# 5997   844489        0
#
# [5998 rows x 2 columns]

# %%
new_df['trip_id'].describe()
# Out:
# count    5998.000000
# mean        2.682894
# std         1.521283
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         8.000000
# Name: trip_id, dtype: float64

# %%
new_df[new_df['trip_id'] > 4].count()
# Out:
# user_id    710
# trip_id    710
# dtype: int64

# %%
# Create conditional DataFrame column by np.select function.
# giving the perk who has more than 4 trip
conditions = [new_df['trip_id'] > 4]

choices = ['yes']
new_df['no_cancellation_fees'] = np.select(conditions, choices, default='no')
print(new_df)
# Out:
#       user_id  trip_id no_cancellation_fees
# 469    485544        8                  yes
# 824    509115        8                  yes
# 1519   517491        8                  yes
# 4438   572554        8                  yes
# 1190   513236        8                  yes
# ...       ...      ...                  ...
# 2656   534082        0                   no
# 2674   534586        0                   no
# 817    509001        0                   no
# 815    508964        0                   no
# 5997   844489        0                   no
#
# [5998 rows x 3 columns]

# %%
# merging
segmented_df = pd.merge(segmented_df, new_df[['user_id', 'no_cancellation_fees']], on='user_id', how='inner')
segmented_df
# Out:
#       user_id free_meal free_checked_bags no_cancellation_fees
# 0      534594       yes                no                   no
# 1      596863       yes               yes                   no
# 2      507805       yes               yes                  yes
# 3      539710       yes                no                   no
# 4      669329       yes                no                   no
# ...       ...       ...               ...                  ...
# 5993   544926        no                no                   no
# 5994   577534        no                no                   no
# 5995   596320        no                no                   no
# 5996   539868        no                no                   no
# 5997   515835        no                no                   no
#
# [5998 rows x 4 columns]

# %% [markdown]
# # Exclusive Discounts

# %%
df.columns
# Out:
# Index(['user_id', 'session_id', 'trip_id', 'session_start', 'session_end',
#        'flight_discount', 'hotel_discount', 'flight_discount_amount',
#        'hotel_discount_amount', 'flight_booked', 'hotel_booked', 'page_clicks',
#        'cancellation', 'birthdate', 'gender', 'married', 'has_children',
#        'home_country', 'home_city', 'home_airport', 'home_airport_lat',
#        'home_airport_lon', 'sign_up_date', 'trip_id.1', 'origin_airport',
#        'destination', 'destination_airport', 'seats', 'return_flight_booked',
#        'departure_time', 'return_time', 'checked_bags', 'trip_airline',
#        'destination_airport_lat', 'destination_airport_lon', 'base_fare_usd',
#        'trip_id.2', 'hotel_name', 'nights', 'rooms', 'check_in_time',
#        'check_out_time', 'hotel_per_room_usd'],
#       dtype='object')

# %%
# all the trip with flight and hotel booking and have flight or hotel discount with no cancellation
new_df = df[
    ((df['trip_id.1'].notnull()) |
    (df['trip_id.2'].notnull())) &
    (df['cancellation'] == False) &
    ((df['flight_discount'] == True) | (df['hotel_discount'] == True))
]
new_df
# Out:
#        user_id                               session_id  \
# 402     548859  548859-9b011308c86d46b0a97af20320b19a73
# 827     532279  532279-1a179e2189424b53bb56f8956d7b6ba5
# 1226    586936  586936-6918ccd72d374640a8b6a04da632d737
# 2293    514980  514980-10bf88c8c7b34ebe926b42cecd1afda0
# 2414    550796  550796-c5e819fdf64740b0bbe89f5c07c1ff21
# ...        ...                                      ...
# 49194   543968  543968-3f85a193b98a4cc899b984bc12e9f5a3
# 49196   549623  549623-c6c4e43755264612b0575e08a07c3f91
# 49197   578872  578872-14c8bf7b96024f969ce8c16f7a69a62a
# 49198   614311  614311-0b76a67ce41843d78389a29dd23d1d79
# 49210   510093  510093-2d3e14a9e10b4a0a942a4312b914e557
#
#                                        trip_id        session_start  \
# 402    548859-b080407b3cdc4692a6c4e9fe4ef85627  2023-01-23 21:03:00
# 827    532279-e8348444247b469eb9bc915beffff053  2023-02-08 13:45:00
# 1226   586936-99d45d8801504ec39c1309a62b837ed0  2023-02-22 19:11:00
# 2293   514980-d924669a4328486f9145dbd416f16fcd  2023-05-07 19:06:00
# 2414   550796-b32bbe55506b47faaedc93a21342984a  2023-05-21 16:22:00
# ...                                        ...                  ...
# 49194  543968-04460895f11c475d9f0e40384d23eac4  2023-04-23 15:26:00
# 49196  549623-e4b934d312c34607a5d9ce4ee70a74ac  2023-04-30 19:57:00
# 49197  578872-d69b6c5a4d0441dab7c64ae1185995d2  2023-06-07 12:21:00
# 49198  614311-d21df59cc4ab4640add93d76b450f37c  2023-06-07 15:37:00
# 49210  510093-e71475580a7c4948ba8f13114a60fa30  2023-07-18 17:06:00
#
#                session_end  flight_discount  hotel_discount  \
# 402    2023-01-23 21:09:52            False            True
# 827    2023-02-08 13:47:34             True           False
# 1226   2023-02-22 19:14:25            False            True
# 2293   2023-05-07 19:09:14            False            True
# 2414   2023-05-21 16:23:17             True           False
# ...                    ...              ...             ...
# 49194  2023-04-23 15:28:16            False            True
# 49196  2023-04-30 19:59:34            False            True
# 49197  2023-06-07 12:23:04             True           False
# 49198  2023-06-07 15:38:06             True           False
# 49210  2023-07-18 17:08:42             True           False
#
#        flight_discount_amount  hotel_discount_amount  flight_booked  ...  \
# 402                       NaN                   0.10           True  ...
# 827                      0.15                    NaN          False  ...
# 1226                      NaN                   0.10          False  ...
# 2293                      NaN                   0.15           True  ...
# 2414                     0.20                    NaN           True  ...
# ...                       ...                    ...            ...  ...
# 49194                     NaN                   0.10           True  ...
# 49196                     NaN                   0.20           True  ...
# 49197                    0.15                    NaN           True  ...
# 49198                    0.05                    NaN           True  ...
# 49210                    0.20                    NaN           True  ...
#
#        destination_airport_lat  destination_airport_lon  base_fare_usd  \
# 402                     51.114                 -114.020         525.80
# 827                        NaN                      NaN            NaN
# 1226                       NaN                      NaN            NaN
# 2293                    49.195                 -123.182         540.78
# 2414                    47.530                 -122.302         614.63
# ...                        ...                      ...            ...
# 49194                   41.786                  -87.752         494.52
# 49196                   29.607                  -95.159         245.61
# 49197                   42.364                  -71.005         214.13
# 49198                   21.222                  105.806        4912.79
# 49210                   50.056                  -97.032         381.22
#
#                                      trip_id.2                  hotel_name  \
# 402    548859-b080407b3cdc4692a6c4e9fe4ef85627      Best Western - calgary
# 827    532279-e8348444247b469eb9bc915beffff053        NH Hotel  - new york
# 1226   586936-99d45d8801504ec39c1309a62b837ed0          Conrad  - new york
# 2293   514980-d924669a4328486f9145dbd416f16fcd  Extended Stay  - vancouver
# 2414                                       NaN                         NaN
# ...                                        ...                         ...
# 49194  543968-04460895f11c475d9f0e40384d23eac4         Radisson  - chicago
# 49196  549623-e4b934d312c34607a5d9ce4ee70a74ac        Shangri-La - houston
# 49197  578872-d69b6c5a4d0441dab7c64ae1185995d2       Crowne Plaza - boston
# 49198                                      NaN                         NaN
# 49210  510093-e71475580a7c4948ba8f13114a60fa30        Marriott  - winnipeg
#
#        nights  rooms            check_in_time       check_out_time  \
# 402       7.0    1.0  2023-01-29 19:05:46.995  2023-02-06 11:00:00
# 827      12.0    2.0      2023-02-15 11:00:00  2023-02-27 11:00:00
# 1226     18.0    1.0      2023-02-27 11:00:00  2023-03-17 11:00:00
# 2293      2.0    1.0   2023-05-13 12:50:40.29  2023-05-16 11:00:00
# 2414      NaN    NaN                      NaN                  NaN
# ...       ...    ...                      ...                  ...
# 49194     1.0    1.0  2023-05-02 12:34:27.795  2023-05-04 11:00:00
# 49196     1.0    1.0  2023-05-07 14:37:17.175  2023-05-09 11:00:00
# 49197     2.0    1.0  2023-06-16 19:29:05.055  2023-06-19 11:00:00
# 49198     NaN    NaN                      NaN                  NaN
# 49210     0.0    1.0   2023-07-30 11:45:27.81  2023-07-30 11:00:00
#
#       hotel_per_room_usd
# 402                269.0
# 827                208.0
# 1226                68.0
# 2293               133.0
# 2414                 NaN
# ...                  ...
# 49194              115.0
# 49196              319.0
# 49197              403.0
# 49198                NaN
# 49210              109.0
#
# [4231 rows x 43 columns]

# %%
new_df = new_df[['user_id']]
new_df
# Out:
#        user_id
# 402     548859
# 827     532279
# 1226    586936
# 2293    514980
# 2414    550796
# ...        ...
# 49194   543968
# 49196   549623
# 49197   578872
# 49198   614311
# 49210   510093
#
# [4231 rows x 1 columns]

# %%
# geting the total trip by each user
new_df = new_df.groupby('user_id', as_index=False).value_counts().sort_values('count', ascending=False)
new_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_df = new_df.groupby('user_id', as_index=False).value_counts().sort_values('count', ascending=False)
#       2 new_df
#
# NameError: name 'new_df' is not defined

# %%
new_df['count'].describe()
# Out:
# count    3106.000000
# mean        1.362202
# std         0.606864
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         6.000000
# Name: count, dtype: float64

# %%
plt.boxplot(new_df['count'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c0e7fb0f10>,
#   <matplotlib.lines.Line2D at 0x1c0e7fb19d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c0e7fb2390>,
#   <matplotlib.lines.Line2D at 0x1c0e7fb2c10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c0e7fb0610>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c0e7fb3410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c0e7fb3d10>],
#  'means': []}

# %%
new_df[new_df['count'] > 1].count()
# Out:
# user_id    939
# count      939
# dtype: int64

# %%
# Create conditional DataFrame column by np.select function.
# giving the perk who has more than 1 trip
conditions = [new_df['count'] > 1]

choices = ['yes']
new_df['exclusive_discounts'] = np.select(conditions, choices, default='no')
print(new_df)
# Out:
#       user_id  count exclusive_discounts
# 2572   589489      6                 yes
# 708    514980      5                 yes
# 1072   524226      4                 yes
# 1919   551804      4                 yes
# 1064   524043      4                 yes
# ...       ...    ...                 ...
# 1228   528706      1                  no
# 1229   528744      1                  no
# 1230   528777      1                  no
# 1232   528828      1                  no
# 3105   801660      1                  no
#
# [3106 rows x 3 columns]

# %%
# merging
segmented_df = pd.merge(segmented_df, new_df[['user_id', 'exclusive_discounts']], on='user_id', how='left')
segmented_df
# Out:
#       user_id free_meal free_checked_bags no_cancellation_fees  \
# 0      534594       yes                no                   no
# 1      596863       yes               yes                   no
# 2      507805       yes               yes                  yes
# 3      539710       yes                no                   no
# 4      669329       yes                no                   no
# ...       ...       ...               ...                  ...
# 5993   544926        no                no                   no
# 5994   577534        no                no                   no
# 5995   596320        no                no                   no
# 5996   539868        no                no                   no
# 5997   515835        no                no                   no
#
#      exclusive_discounts
# 0                     no
# 1                     no
# 2                    yes
# 3                    yes
# 4                     no
# ...                  ...
# 5993                  no
# 5994                  no
# 5995                  no
# 5996                  no
# 5997                  no
#
# [5998 rows x 5 columns]

# %%
segmented_df.isna().sum() # calculating the total NA cell
# Out:
# user_id                    0
# free_meal                  0
# free_checked_bags          0
# no_cancellation_fees       0
# exclusive_discounts     1059
# dtype: int64

# %% [markdown]
# # 1 night free hotel with flight

# %%
df.columns
# Out:
# Index(['user_id', 'session_id', 'trip_id', 'session_start', 'session_end',
#        'flight_discount', 'hotel_discount', 'flight_discount_amount',
#        'hotel_discount_amount', 'flight_booked', 'hotel_booked', 'page_clicks',
#        'cancellation', 'birthdate', 'gender', 'married', 'has_children',
#        'home_country', 'home_city', 'home_airport', 'home_airport_lat',
#        'home_airport_lon', 'sign_up_date', 'trip_id.1', 'origin_airport',
#        'destination', 'destination_airport', 'seats', 'return_flight_booked',
#        'departure_time', 'return_time', 'checked_bags', 'trip_airline',
#        'destination_airport_lat', 'destination_airport_lon', 'base_fare_usd',
#        'trip_id.2', 'hotel_name', 'nights', 'rooms', 'check_in_time',
#        'check_out_time', 'hotel_per_room_usd'],
#       dtype='object')

# %%
# all the trip with flight and hotel booking
new_df = df[(df['trip_id.1'].notnull()) & (df['trip_id.2'].notnull())]

new_df
# Out:
#        user_id                               session_id  \
# 402     548859  548859-9b011308c86d46b0a97af20320b19a73
# 869     575774  575774-7484f82c3fcc4338a6ee98f37dfe4733
# 947     548504  548504-c1f4807f7ced41a7ae4c268416b98870
# 1072    555770  555770-ea2787aad15a434da2893e8ed54bfe79
# 1165    524861  524861-3d7d2c5ddd2a49038fa07e91f1f3f749
# ...        ...                                      ...
# 49205   438551  438551-f1073b8a5a844032a33256666ee6c47f
# 49207   480313  480313-f46ac4d965a2410e84ddf400ede116ad
# 49208   534295  534295-0a137c45cac34b1e834f23ecab4233fb
# 49208         Aman Resorts - san diego    8.0    4.0    2023-07-20 20:54:53.1
# 49209  InterContinental  - san antonio    1.0    2.0   2023-07-22 15:22:38.37
# 49210             Marriott  - winnipeg    0.0    1.0   2023-07-30 11:45:27.81
#
#             check_out_time hotel_per_room_usd total_hotel_spent
# 402    2023-02-06 11:00:00              269.0            1883.0
# 869    2023-02-21 11:00:00              134.0             670.0
# 947    2023-02-20 11:00:00              497.0               0.0
# 1072   2023-03-07 11:00:00              125.0            1125.0
# 1165   2023-03-02 11:00:00              106.0             106.0
# ...                    ...                ...               ...
# 49205  2023-10-23 11:00:00              143.0            5577.0
# 49207  2023-02-15 11:00:00              174.0             348.0
# 49208  2023-07-29 11:00:00               85.0            2720.0
# 49209  2023-07-24 11:00:00               80.0             160.0
# 49210  2023-07-30 11:00:00              109.0               0.0
#
# [12294 rows x 44 columns]

# %%
new_df['nights'].describe()
# Out:
# count    12294.000000
# mean         2.895152
# std          2.953638
# min         -2.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max         34.000000
# Name: nights, dtype: float64

# %%
plt.boxplot(new_df.nights)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1afc33816d0>,
#   <matplotlib.lines.Line2D at 0x1afc33821d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1afc550b950>,
#   <matplotlib.lines.Line2D at 0x1afc5509c90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1afc3380e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1afc550a890>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1afc33820d0>],
#  'means': []}

# %%
# stays more than 4 nights
new_df = new_df[new_df['nights'] > 4]
new_df
# Out:
#        user_id                               session_id  \
# 402     548859  548859-9b011308c86d46b0a97af20320b19a73
# 869     575774  575774-7484f82c3fcc4338a6ee98f37dfe4733
# 1072    555770  555770-ea2787aad15a434da2893e8ed54bfe79
# 1965    669356  669356-2b2b699d58394016ad7627eec9d2da8e
# 2498    527783  527783-1a76157a50624b28a722d2b99e22f1f8
# ...        ...                                      ...
# 49188   512556  512556-2ca5fa4d3d77424582d639babc982081
# 49195   547663  547663-aa3f46fff9b1481c9e793ab01a75f52b
# 49201   569792  569792-9548f5c3c32645e1aba3d6364ba2a309
# 49205   438551  438551-f1073b8a5a844032a33256666ee6c47f
# 49208   534295  534295-0a137c45cac34b1e834f23ecab4233fb
#
#                                        trip_id        session_start  \
# 402    548859-b080407b3cdc4692a6c4e9fe4ef85627  2023-01-23 21:03:00
# 869    575774-c1f81bbaea8841c8a13619fec71042e5  2023-02-08 16:27:00
# 1072   555770-a75973f7da3e4e1c8345b378058696bb  2023-02-17 22:20:00
# 1965   669356-22a4da32154842f2b23f6c3554856a47  2023-03-28 11:12:00
# 2498   527783-1362fa86f10c4e3980fe70eccd2e3e1c  2023-01-23 23:14:00
# ...                                        ...                  ...
# 49188  512556-3a36970290da41daa3399fcd1ab19ab1  2023-02-10 11:51:00
# 49195  547663-a76f50cb1e314dd792c3be1e20805e17  2023-04-23 21:10:00
# 49201  569792-a4c280afaf9d4412bf0707bb2c3c50d4  2023-06-17 14:30:00
# 49205  438551-1a9fcfc16bd8487ea23e820957d23279  2023-05-31 21:03:37
# 49208  534295-3e20b84b40c946b1a8124395231d4412  2023-07-10 18:55:00
# 2502   526683-48186b49275c426bb8ac0efa03ba2423       Wyndham - los angeles
# 2510   606862-463bc95797ee4e49bd27ed13f590e594           Fairmont - dallas
# ...                                        ...                         ...
# 49188  512556-3a36970290da41daa3399fcd1ab19ab1         Wyndham - milwaukee
# 49195  547663-a76f50cb1e314dd792c3be1e20805e17  Four Seasons - los angeles
# 49201  569792-a4c280afaf9d4412bf0707bb2c3c50d4       Four Seasons - dallas
# 49205  438551-1a9fcfc16bd8487ea23e820957d23279         Crowne Plaza - agra
# 49208  534295-3e20b84b40c946b1a8124395231d4412    Aman Resorts - san diego
#
#       nights  rooms            check_in_time       check_out_time  \
# 402      7.0    1.0  2023-01-29 19:05:46.995  2023-02-06 11:00:00
# 1965     5.0    1.0   2023-04-10 18:39:16.29  2023-04-16 11:00:00
# 2498    11.0    1.0  2023-01-30 12:01:19.515  2023-02-11 11:00:00
# 2502     6.0    1.0   2023-02-28 11:44:13.47  2023-03-06 11:00:00
# 2510     5.0    1.0   2023-03-27 12:04:50.43  2023-04-02 11:00:00
# ...      ...    ...                      ...                  ...
# 49188    7.0    3.0  2023-02-19 11:32:55.365  2023-02-26 11:00:00
# 49195    6.0    1.0   2023-04-29 18:12:23.85  2023-05-06 11:00:00
# 49201    6.0    1.0  2023-06-24 13:28:43.185  2023-07-01 11:00:00
# 49205   13.0    3.0   2023-10-10 00:55:04.08  2023-10-23 11:00:00
# 49208    8.0    4.0    2023-07-20 20:54:53.1  2023-07-29 11:00:00
#
#       hotel_per_room_usd total_hotel_spent
# 402                269.0            1883.0
# 1965               141.0             705.0
# 2498               148.0            1628.0
# 2502               189.0            1134.0
# 2510               140.0             700.0
# ...                  ...               ...
# 49188              284.0            5964.0
# 49195              152.0             912.0
# 49201              151.0             906.0
# 49205              143.0            5577.0
# 49208               85.0            2720.0
#
# [2123 rows x 44 columns]

# %%
new_df = new_df[['user_id']]
new_df
# Out:
#        user_id
# 402     548859
# 1965    669356
# 2498    527783
# 2502    526683
# 2510    606862
# ...        ...
# 49188   512556
# 49195   547663
# 49201   569792
# 49205   438551
# 49208   534295
#
# [2123 rows x 1 columns]

# %%
# counting the total trip by each user
new_df = new_df.groupby('user_id', as_index=False).value_counts().sort_values('count', ascending=False)
new_df
# Out:
#       user_id  count
# 197    507805      5
# 190    505916      4
# 237    510114      4
# 483    519859      4
# 794    534351      4
# ...       ...    ...
# 644    526431      1
# 642    526367      1
# 641    526365      1
# 640    526354      1
# 1698   811077      1
#
# [1699 rows x 2 columns]

# %%
new_df[new_df['count'] >= 2].count()
# Out:
# user_id    366
# count      366
# dtype: int64

# %%
# Create conditional DataFrame column by np.select function.
conditions = [new_df['count'] >= 2]
# giving the perk who trip at least 2 times
choices = ['yes']
new_df['free_hotel_night'] = np.select(conditions, choices, default='no')
print(new_df)
# Out:
#       user_id  count free_hotel_night
# 197    507805      5              yes
# 190    505916      4              yes
# 237    510114      4              yes
# 483    519859      4              yes
# 794    534351      4              yes
# ...       ...    ...              ...
# 644    526431      1               no
# 642    526367      1               no
# 641    526365      1               no
# 640    526354      1               no
# 1698   811077      1               no
#
# [1699 rows x 3 columns]

# %%
# merging
segmented_df = pd.merge(segmented_df, new_df[['user_id', 'free_hotel_night']], on='user_id', how='left')
segmented_df
# Out:
#       user_id free_meal free_checked_bags no_cancellation_fees  \
# 0      534594       yes                no                   no
# 1      596863       yes               yes                   no
# 2      507805       yes               yes                  yes
# 3      539710       yes                no                   no
# 4      669329       yes                no                   no
# ...       ...       ...               ...                  ...
# 5993   544926        no                no                   no
# 5994   577534        no                no                   no
# 5995   596320        no                no                   no
# 5996   539868        no                no                   no
# 5997   515835        no                no                   no
#
#      exclusive_discounts free_hotel_night
# 0                     no              NaN
# 1                     no              yes
# 2                    yes              yes
# 3                    yes               no
# 4                     no               no
# ...                  ...              ...
# 5993                  no              NaN
# 5994                  no              NaN
# 5995                  no              NaN
# 5996                  no              NaN
# 5997                  no              NaN
#
# [5998 rows x 6 columns]

# %%
segmented_df.isna().sum()
# Out:
# user_id                    0
# free_meal                  0
# free_checked_bags          0
# no_cancellation_fees       0
# exclusive_discounts     1059
# free_hotel_night        4299
# dtype: int64

# %%
# filling all the NA
segmented_df['exclusive_discounts'] = segmented_df['exclusive_discounts'].fillna('no')
segmented_df['free_hotel_night'] = segmented_df['free_hotel_night'].fillna('no')
segmented_df.isna().sum()
# Out:
# user_id                 0
# free_meal               0
# free_checked_bags       0
# no_cancellation_fees    0
# exclusive_discounts     0
# free_hotel_night        0
# dtype: int64

# %%
# save the dataset
segmented_df.to_csv('travelTide_customer_segmented_dataset.csv', index=False)

# %%
import matplotlib.pyplot as plt # for plotting

# %%
new = segmented_df.iloc[:, 1:] # all the column except user_id

# %%
# Count 'yes' values in each column
yes_counts = new.eq('yes').sum()

# %%
# Create a bar chart
plt.bar(yes_counts.index, yes_counts.values) # bar plot
plt.xlabel('Perks') # plot x label
plt.ylabel('Total user') # plot y label
plt.title('Total users in each perks') # plot title
plt.xticks(rotation=20) # rorate x tickes

# Add value labels on top of bars
for i, value in enumerate(yes_counts.values):
    plt.text(i, value + 0.1, str(value), ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show() # show the plot

# %%
# total number of no perks user

segment_df[(segment_df['free_meal'] == 'no') & 
          (segment_df['free_checked_bags'] == 'no') & 
          (segment_df['no_cancellation_fees'] == 'no') & 
          (segment_df['free_hotel_night'] == 'no') & 
          (segment_df['exclusive_discounts'] == 'no')]
# Out:
#       Unnamed: 0  user_id free_meal free_checked_bags no_cancellation_fees  \
# 1770        1770   521748        no                no                   no
# 1772        1772   530468        no                no                   no
# 1773        1773   565565        no                no                   no
# 1774        1774   652737        no                no                   no
# 1775        1775   425632        no                no                   no
# ...          ...      ...       ...               ...                  ...
# 5990        5990   535155        no                no                   no
# 5994        5994   577534        no                no                   no
# 5995        5995   596320        no                no                   no
# 5996        5996   539868        no                no                   no
# 5997        5997   515835        no                no                   no
#
#      free_hotel_night exclusive_discounts
# 1770               no                  no
# 1772               no                  no
# 1773               no                  no
# 1774               no                  no
# 1775               no                  no
# ...               ...                 ...
# 5990               no                  no
# 5994               no                  no
# 5995               no                  no
# 5996               no                  no
# 5997               no                  no
#
# [3120 rows x 7 columns]
