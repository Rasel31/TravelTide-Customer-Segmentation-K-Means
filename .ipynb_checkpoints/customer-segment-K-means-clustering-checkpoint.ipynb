# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
segment_df = pd.read_csv('travelTide_customer_segmented_dataset-kmeans.csv')
segment_df
# Out:
#       user_id  total_hotel_spent  checked_bags  trip_id  night_stay  \
# 0      534594            28114.0           0.0        2         0.0
# 1      596863            27489.0           4.0        3         0.0
# 2      507805            27241.0           6.0        5         1.0
# 3      539710            22619.0           1.0        4         1.0
# 4      669329            22356.0           0.0        2         0.0
# ...       ...                ...           ...      ...         ...
# 5993   544926             -349.0           0.0        3         2.0
# 5994   577534             -398.0           1.0        1         1.0
# 5995   596320             -477.0           2.0        2         1.0
# 5996   539868             -562.0           1.0        3         1.0
# 5997   515835             -575.0           1.0        3         0.0
#
#       discounted_trip
# 0                 0.0
# 1                 0.0
# 2                 1.0
# 3                 1.0
# 4                 0.0
# ...               ...
# 5993              2.0
# 5994              1.0
# 5995              1.0
# 5996              1.0
# 5997              0.0
#
# [5998 rows x 6 columns]

# %%
# Select relevant metrics for clustering
metrics = ['total_hotel_spent', 'checked_bags', 'trip_id', 'discounted_trip', 'night_stay']
X = segment_df[metrics]

# %%
X
# Out:
#       total_hotel_spent  checked_bags  trip_id  discounted_trip  night_stay
# 0               28114.0           0.0        2              0.0         0.0
# 1               27489.0           4.0        3              0.0         0.0
# 2               27241.0           6.0        5              1.0         1.0
# 3               22619.0           1.0        4              1.0         1.0
# 4               22356.0           0.0        2              0.0         0.0
# ...                 ...           ...      ...              ...         ...
# 5993             -349.0           0.0        3              2.0         2.0
# 5994             -398.0           1.0        1              1.0         1.0
# 5995             -477.0           2.0        2              1.0         1.0
# 5996             -562.0           1.0        3              1.0         1.0
# 5997             -575.0           1.0        3              0.0         0.0
#
# [5998 rows x 5 columns]

# %%
# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[11.20235436, -0.97483371, -0.44893115, -0.87229095, -0.87229095],
#        [10.93475753,  1.78940341,  0.20846364, -0.87229095, -0.87229095],
#        [10.8285751 ,  3.17152197,  1.52325321,  0.36429641,  0.36429641],
#        ...,
#        [-1.03902354,  0.40728485, -0.44893115,  0.36429641,  0.36429641],
#        [-1.07541671, -0.28377443,  0.20846364,  0.36429641,  0.36429641],
#        [-1.08098272, -0.28377443,  0.20846364, -0.87229095, -0.87229095]])

# %%
# Apply K-means clustering
num_clusters = 5  # Number of clusters
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
segment_df['cluster'] = kmeans.fit_predict(X_scaled)
# Out:
# C:\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Assign perks based on cluster
def assign_perk(cluster_id):
    if cluster_id == 0:
        return 'Free Hotel Meal'
    elif cluster_id == 1:
        return 'Free Checked Bag'
    elif cluster_id == 2:
        return 'No Cancellation Fees'
    elif cluster_id == 3:
        return 'Exclusive discounts'
    elif cluster_id == 4:
        return '1 night free hotel with flight'

segment_df['perk'] = segment_df['cluster'].apply(assign_perk)

# %%
segment_df[['user_id', 'cluster', 'perk']]
# Out:
#       user_id  cluster                 perk
# 0      534594        3  Exclusive discounts
# 1      596863        3  Exclusive discounts
# 2      507805        3  Exclusive discounts
# 3      539710        3  Exclusive discounts
# 4      669329        3  Exclusive discounts
# ...       ...      ...                  ...
# 5993   544926        1     Free Checked Bag
# 5994   577534        1     Free Checked Bag
# 5995   596320        1     Free Checked Bag
# 5996   539868        1     Free Checked Bag
# 5997   515835        0      Free Hotel Meal
#
# [5998 rows x 3 columns]

# %%
segment_df
# Out:
#       user_id  total_hotel_spent  checked_bags  trip_id  night_stay  \
# 0      534594            28114.0           0.0        2         0.0
# 1      596863            27489.0           4.0        3         0.0
# 2      507805            27241.0           6.0        5         1.0
# 3      539710            22619.0           1.0        4         1.0
# 4      669329            22356.0           0.0        2         0.0
# ...       ...                ...           ...      ...         ...
# 5993   544926             -349.0           0.0        3         2.0
# 5994   577534             -398.0           1.0        1         1.0
# 5995   596320             -477.0           2.0        2         1.0
# 5996   539868             -562.0           1.0        3         1.0
# 5997   515835             -575.0           1.0        3         0.0
#
#       discounted_trip  cluster                 perk
# 0                 0.0        3  Exclusive discounts
# 1                 0.0        3  Exclusive discounts
# 2                 1.0        3  Exclusive discounts
# 3                 1.0        3  Exclusive discounts
# 4                 0.0        3  Exclusive discounts
# ...               ...      ...                  ...
# 5993              2.0        1     Free Checked Bag
# 5994              1.0        1     Free Checked Bag
# 5995              1.0        1     Free Checked Bag
# 5996              1.0        1     Free Checked Bag
# 5997              0.0        0      Free Hotel Meal
#
# [5998 rows x 8 columns]

# %%
segment_df.to_csv('travelTide_customer_segmented_dataset-kmeans-applied.csv', index=False)

# %%
import matplotlib.pyplot as plt

# %%
# Group by 'perk' column and count rows in each group
grouped = segment_df.groupby('perk').size().reset_index(name='Count')

# Create a bar plot
plt.bar(grouped['perk'], grouped['Count'])
plt.xlabel('Perks')
plt.ylabel('Total users')
plt.title('User vs Perk (K-Means)')
plt.xticks(rotation=20)

# Add value labels on top of bars
for i, value in enumerate(grouped['Count']):
    plt.text(i, value + 0.1, str(value), ha='center', va='bottom', fontsize=10)

    
plt.show()

# %%
grouped
# Out:
#                              perk  Count
# 0  1 night free hotel with flight   1399
# 1             Exclusive discounts    276
# 2                Free Checked Bag   1444
# 3                 Free Hotel Meal   2024
# 4            No Cancellation Fees    855
